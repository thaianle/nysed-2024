# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
nysed_2024_read = pd.read_csv('data/nysed_2024_preprocessing.csv')
nysed_2024_read.head()
# Out:
#    INSTITUTION_ID    ENTITY_CD                           ENTITY_NAME  \
# 0    800000055743  10100010034                    ALBANY HIGH SCHOOL
# 1    800000055479  10201040001  BERNE-KNOX-WESTERLO JUNIOR-SENIOR HS
# 2    800000055439  10306060008  BETHLEHEM CENTRAL SENIOR HIGH SCHOOL
# 3    800000055436  10402060001         RAVENA-COEYMANS-SELKIRK SR HS
# 4    800000055426  10500010007                    COHOES HIGH SCHOOL
#
#    WEIGHTED_INDEX  ENROLLMENT  ABSENT_COUNT  GRAD_COUNT  COHORT_COUNT  \
# 0            82.2        3046          1550         549           704
# 1           142.3         222            42          47            53
# 2           198.1        1374           155         333           349
# 3           129.2         530           164         118           133
# 4            94.0         619           326         109           132
#
#    ELA_P_RATE  MATH_P_RATE  PUPIL_COUNT_TOT  FED_STATE_LOCAL_EXP  NUM_TEACH  \
# ...
